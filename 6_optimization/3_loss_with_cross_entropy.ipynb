# %%
import tensorflow as tf
import pickle
import numpy as np
from tensorflow import keras


def load(data_path):
    with open(data_path,'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]

class MnistData:
    def __init__(self, filenames, need_shuffle, datatype='training'):
        all_data = []
        all_labels = []
        x_train, y_train, x_test, y_test = load(filenames) #"data/mnist.pkl"
        
        if datatype=='training':
            self._data = x_train / 127.5 -1
            self._labels = y_train
            print(self._data.shape)
            print(self._labels.shape)
        else:
            self._data = x_test / 127.5 -1
            self._labels = y_test
            print(self._data.shape)
            print(self._labels.shape)
            
        self._num_examples = self._data.shape[0]
        self._need_shuffle = need_shuffle
        self._indicator = 0
        if self._need_shuffle:
            self._shuffle_data()
            
    def _shuffle_data(self):
        # [0,1,2,3,4,5] -> [5,3,2,4,0,1]
        p = np.random.permutation(self._num_examples)
        self._data = self._data[p]
        self._labels = self._labels[p]
    
    def next_batch(self, batch_size):
        """return batch_size examples as a batch."""
        end_indicator = self._indicator + batch_size
        if end_indicator > self._num_examples:
            if self._need_shuffle:
                self._shuffle_data()
                self._indicator = 0
                end_indicator = batch_size
            else:
                raise Exception("have no more examples")
        if end_indicator > self._num_examples:
            raise Exception("batch size is larger than all examples")
        batch_data = self._data[self._indicator: end_indicator]
        batch_labels = self._labels[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_data, batch_labels

# %%
data = "../4_basic_image_recognition/data/mnist.pkl"
train_data = MnistData(data, True, 'training')
test_data = MnistData(data, False, 'test')

# %%
#x = tf.placeholder(tf.float32, [None, 28*28])
#y = tf.placeholder(tf.int64, [None])
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.int64, [None])

x_image = tf.reshape(x, [-1, 28, 28, 1])

conv_1 = tf.layers.conv2d(inputs=x_image, 
                          filters=32, 
                          kernel_size=(5, 5),
                          padding = 'same',
                          activation=tf.nn.relu,
                          name='conv1')

pool1 = tf.layers.max_pooling2d(inputs=conv_1,
                                pool_size=(2, 2),
                                strides=(2,2),
                                name='pool1')

conv_2 = tf.layers.conv2d(inputs=pool1,
                          filters=64,
                          kernel_size=(5, 5),
                          padding = 'same',
                          activation=tf.nn.relu,
                          name='conv2')

pool2 = tf.layers.max_pooling2d(inputs=conv_2,
                                pool_size=(2,2),
                                strides=(2,2),
                                name='pool2')

# fc layer1
flatten = tf.layers.flatten(pool2, name='flatten')
# fc layer2
y_ = tf.layers.dense(flatten, 10)

#sparse_softmax_cross_entropy include one_hot encoding
loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)
predict = tf.argmax(y_, 1)
correct_prediction = tf.equal(predict, y)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float64))
with tf.name_scope('train_op'):
    train_op = tf.train.AdamOptimizer(1e-4).minimize(loss)

# %%
init = tf.global_variables_initializer()
batch_size = 20
train_steps = 10000
test_steps = 50

# train 10k: %
with tf.Session() as sess:
    sess.run(init)
    for i in range(train_steps):
        batch_data, batch_labels = train_data.next_batch(batch_size)
        loss_val, acc_val, _ = sess.run([loss, accuracy, train_op], feed_dict={x: batch_data, y: batch_labels})
        
        if (i+1) % 100 == 0:
            print('[Train] Step: %d, loss: %4.5f, acc: %4.5f' % (i+1, loss_val, acc_val))
            
        if (i+1) % 1000 == 0:
            all_test_acc_val = []
            for j in range(test_steps):
                test_batch_data, test_batch_labels = test_data.next_batch(batch_size)
                test_acc_val = sess.run([accuracy], feed_dict = {x: test_batch_data, y: test_batch_labels})
                all_test_acc_val.append(test_acc_val)
            test_acc = np.mean(all_test_acc_val)
            print('[Test ] Step: %d, acc: %4.5f' % (i+1, test_acc))

# %% [raw]
# Cross_Entropy - AdamOptimizer with 1e-3
# ##############################################
#
# [Train] Step: 100, loss: 0.23317, acc: 0.95000
# [Train] Step: 200, loss: 0.05127, acc: 1.00000
# [Train] Step: 300, loss: 0.01501, acc: 1.00000
# [Train] Step: 400, loss: 0.12856, acc: 0.95000
# [Train] Step: 500, loss: 0.02021, acc: 1.00000
# [Train] Step: 600, loss: 0.00310, acc: 1.00000
# [Train] Step: 700, loss: 0.07143, acc: 0.95000
# [Train] Step: 800, loss: 0.02700, acc: 1.00000
# [Train] Step: 900, loss: 0.47600, acc: 0.85000
# [Train] Step: 1000, loss: 0.00224, acc: 1.00000
# [Test ] Step: 1000, acc: 0.97700
# [Train] Step: 1100, loss: 0.10400, acc: 0.95000
# [Train] Step: 1200, loss: 0.00838, acc: 1.00000
# [Train] Step: 1300, loss: 0.00450, acc: 1.00000
# [Train] Step: 1400, loss: 0.00088, acc: 1.00000
# [Train] Step: 1500, loss: 0.01541, acc: 1.00000
# [Train] Step: 1600, loss: 0.00119, acc: 1.00000
# [Train] Step: 1700, loss: 0.05430, acc: 1.00000
# [Train] Step: 1800, loss: 0.16319, acc: 0.95000
# [Train] Step: 1900, loss: 0.00107, acc: 1.00000
# [Train] Step: 2000, loss: 0.02954, acc: 1.00000
# [Test ] Step: 2000, acc: 0.97500
# [Train] Step: 2100, loss: 0.00483, acc: 1.00000
# [Train] Step: 2200, loss: 0.00305, acc: 1.00000
# [Train] Step: 2300, loss: 0.06426, acc: 0.95000
# [Train] Step: 2400, loss: 0.01002, acc: 1.00000
# [Train] Step: 2500, loss: 0.01546, acc: 1.00000
# [Train] Step: 2600, loss: 0.02789, acc: 1.00000
# [Train] Step: 2700, loss: 0.05410, acc: 0.95000
# [Train] Step: 2800, loss: 0.01657, acc: 1.00000
# [Train] Step: 2900, loss: 0.00179, acc: 1.00000
# [Train] Step: 3000, loss: 0.02567, acc: 1.00000
# [Test ] Step: 3000, acc: 0.97800
# [Train] Step: 3100, loss: 0.34845, acc: 0.95000
# [Train] Step: 3200, loss: 0.02394, acc: 1.00000
# [Train] Step: 3300, loss: 0.00032, acc: 1.00000
# [Train] Step: 3400, loss: 0.00681, acc: 1.00000
# [Train] Step: 3500, loss: 0.00334, acc: 1.00000
# [Train] Step: 3600, loss: 0.01041, acc: 1.00000
# [Train] Step: 3700, loss: 0.06685, acc: 0.95000
# [Train] Step: 3800, loss: 0.00033, acc: 1.00000
# [Train] Step: 3900, loss: 0.00749, acc: 1.00000
# [Train] Step: 4000, loss: 0.12050, acc: 0.95000
# [Test ] Step: 4000, acc: 0.97700
# [Train] Step: 4100, loss: 0.04504, acc: 1.00000
# [Train] Step: 4200, loss: 0.12257, acc: 0.95000
# [Train] Step: 4300, loss: 0.00283, acc: 1.00000
# [Train] Step: 4400, loss: 0.00103, acc: 1.00000
# [Train] Step: 4500, loss: 0.00711, acc: 1.00000
# [Train] Step: 4600, loss: 0.02375, acc: 1.00000
# [Train] Step: 4700, loss: 0.00062, acc: 1.00000
# [Train] Step: 4800, loss: 0.01194, acc: 1.00000
# [Train] Step: 4900, loss: 0.00686, acc: 1.00000
# [Train] Step: 5000, loss: 0.09436, acc: 0.95000
# [Test ] Step: 5000, acc: 0.98500

# %% [raw]
# Cross_Entropy - AdamOptimizer with 1e-4
# ##############################################
# [Train] Step: 100, loss: 1.67131, acc: 0.85000
# [Train] Step: 200, loss: 0.66459, acc: 0.90000
# [Train] Step: 300, loss: 0.57226, acc: 0.85000
# [Train] Step: 400, loss: 0.34743, acc: 0.90000
# [Train] Step: 500, loss: 0.30521, acc: 0.95000
# [Train] Step: 600, loss: 0.12780, acc: 1.00000
# [Train] Step: 700, loss: 0.45408, acc: 0.75000
# [Train] Step: 800, loss: 0.42833, acc: 0.90000
# [Train] Step: 900, loss: 0.19007, acc: 0.95000
# [Train] Step: 1000, loss: 0.19950, acc: 0.95000
# [Test ] Step: 1000, acc: 0.94200
# [Train] Step: 1100, loss: 0.29952, acc: 0.90000
# [Train] Step: 1200, loss: 0.05125, acc: 1.00000
# [Train] Step: 1300, loss: 0.10958, acc: 0.95000
# [Train] Step: 1400, loss: 0.10703, acc: 1.00000
# [Train] Step: 1500, loss: 0.05429, acc: 0.95000
# [Train] Step: 1600, loss: 0.06267, acc: 0.95000
# [Train] Step: 1700, loss: 0.15989, acc: 0.95000
# [Train] Step: 1800, loss: 0.08802, acc: 1.00000
# [Train] Step: 1900, loss: 0.08302, acc: 0.95000
# [Train] Step: 2000, loss: 0.05268, acc: 0.95000
# [Test ] Step: 2000, acc: 0.94600
# [Train] Step: 2100, loss: 0.22248, acc: 0.95000
# [Train] Step: 2200, loss: 0.04703, acc: 1.00000
# [Train] Step: 2300, loss: 0.01033, acc: 1.00000
# [Train] Step: 2400, loss: 0.13635, acc: 0.95000
# [Train] Step: 2500, loss: 0.04090, acc: 1.00000
# [Train] Step: 2600, loss: 0.13114, acc: 0.95000
# [Train] Step: 2700, loss: 0.03816, acc: 1.00000
# [Train] Step: 2800, loss: 0.23030, acc: 0.95000
# [Train] Step: 2900, loss: 0.06416, acc: 1.00000
# [Train] Step: 3000, loss: 0.19970, acc: 0.90000
# [Test ] Step: 3000, acc: 0.96800
# [Train] Step: 3100, loss: 0.03466, acc: 1.00000
# [Train] Step: 3200, loss: 0.00366, acc: 1.00000
# [Train] Step: 3300, loss: 0.02894, acc: 1.00000
# [Train] Step: 3400, loss: 0.17462, acc: 0.90000
# [Train] Step: 3500, loss: 0.04972, acc: 0.95000
# [Train] Step: 3600, loss: 0.01128, acc: 1.00000
# [Train] Step: 3700, loss: 0.01249, acc: 1.00000
# [Train] Step: 3800, loss: 0.01172, acc: 1.00000
# [Train] Step: 3900, loss: 0.01369, acc: 1.00000
# [Train] Step: 4000, loss: 0.06508, acc: 1.00000
# [Test ] Step: 4000, acc: 0.96800
# [Train] Step: 4100, loss: 0.02112, acc: 1.00000
# [Train] Step: 4200, loss: 0.04531, acc: 1.00000
# [Train] Step: 4300, loss: 0.11072, acc: 0.95000
# [Train] Step: 4400, loss: 0.03491, acc: 1.00000
# [Train] Step: 4500, loss: 0.02141, acc: 1.00000
# [Train] Step: 4600, loss: 0.10255, acc: 0.95000
# [Train] Step: 4700, loss: 0.01841, acc: 1.00000
# [Train] Step: 4800, loss: 0.00657, acc: 1.00000
# [Train] Step: 4900, loss: 0.08092, acc: 1.00000
# [Train] Step: 5000, loss: 0.06893, acc: 1.00000
# [Test ] Step: 5000, acc: 0.96900
# [Train] Step: 5100, loss: 0.02985, acc: 1.00000
# [Train] Step: 5200, loss: 0.00606, acc: 1.00000
# [Train] Step: 5300, loss: 0.12597, acc: 0.95000
# [Train] Step: 5400, loss: 0.04160, acc: 0.95000
# [Train] Step: 5500, loss: 0.05556, acc: 1.00000
# [Train] Step: 5600, loss: 0.06480, acc: 1.00000
# [Train] Step: 5700, loss: 0.01470, acc: 1.00000
# [Train] Step: 5800, loss: 0.01754, acc: 1.00000
# [Train] Step: 5900, loss: 0.00403, acc: 1.00000
# [Train] Step: 6000, loss: 0.06238, acc: 0.95000
# [Test ] Step: 6000, acc: 0.99400
# [Train] Step: 6100, loss: 0.23353, acc: 0.95000
# [Train] Step: 6200, loss: 0.02143, acc: 1.00000
# [Train] Step: 6300, loss: 0.12479, acc: 0.95000
# [Train] Step: 6400, loss: 0.04004, acc: 1.00000
# [Train] Step: 6500, loss: 0.21151, acc: 0.95000
# [Train] Step: 6600, loss: 0.00598, acc: 1.00000
# [Train] Step: 6700, loss: 0.03699, acc: 1.00000
# [Train] Step: 6800, loss: 0.02180, acc: 1.00000
# [Train] Step: 6900, loss: 0.02519, acc: 1.00000
# [Train] Step: 7000, loss: 0.20579, acc: 0.95000
# [Test ] Step: 7000, acc: 0.99300
# [Train] Step: 7100, loss: 0.10653, acc: 0.95000
# [Train] Step: 7200, loss: 0.01563, acc: 1.00000
# [Train] Step: 7300, loss: 0.09637, acc: 0.95000
# [Train] Step: 7400, loss: 0.01000, acc: 1.00000
# [Train] Step: 7500, loss: 0.00805, acc: 1.00000
# [Train] Step: 7600, loss: 0.12569, acc: 0.95000
# [Train] Step: 7700, loss: 0.00710, acc: 1.00000
# [Train] Step: 7800, loss: 0.09350, acc: 0.95000
# [Train] Step: 7900, loss: 0.07128, acc: 1.00000
# [Train] Step: 8000, loss: 0.05385, acc: 0.95000
# [Test ] Step: 8000, acc: 0.99700
# [Train] Step: 8100, loss: 0.03183, acc: 1.00000
# [Train] Step: 8200, loss: 0.00649, acc: 1.00000
# [Train] Step: 8300, loss: 0.01009, acc: 1.00000
# [Train] Step: 8400, loss: 0.00770, acc: 1.00000
# [Train] Step: 8500, loss: 0.04879, acc: 1.00000
# [Train] Step: 8600, loss: 0.01311, acc: 1.00000
# [Train] Step: 8700, loss: 0.13463, acc: 0.95000
# [Train] Step: 8800, loss: 0.17698, acc: 0.90000
# [Train] Step: 8900, loss: 0.04077, acc: 1.00000
# [Train] Step: 9000, loss: 0.06886, acc: 0.95000
# [Test ] Step: 9000, acc: 0.99700
# [Train] Step: 9100, loss: 0.00653, acc: 1.00000
# [Train] Step: 9200, loss: 0.00914, acc: 1.00000
# [Train] Step: 9300, loss: 0.01890, acc: 1.00000
# [Train] Step: 9400, loss: 0.02423, acc: 1.00000
# [Train] Step: 9500, loss: 0.00672, acc: 1.00000
# [Train] Step: 9600, loss: 0.01438, acc: 1.00000
# [Train] Step: 9700, loss: 0.07223, acc: 0.95000
# [Train] Step: 9800, loss: 0.05832, acc: 0.95000
# [Train] Step: 9900, loss: 0.09447, acc: 1.00000
# [Train] Step: 10000, loss: 0.01832, acc: 1.00000
# [Test ] Step: 10000, acc: 0.97800
